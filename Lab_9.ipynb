# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshatupadhaya/APS-LAB/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
import heapq

# Function to build graph from user input
def build_graph():
    graph = {}
    n = int(input("Enter number of nodes: "))
    for _ in range(n):
        node = input("Enter node name: ").strip()
        graph[node] = {}
    e = int(input("Enter number of edges: "))
    for _ in range(e):
        u = input("Enter start node: ").strip()
        v = input("Enter end node: ").strip()
        w = int(input(f"Enter weight from {u} to {v}: "))
        graph[u][v] = w
        graph[v][u] = w   # if undirected
    return graph

# Dijkstra’s algorithm
def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    distances[start] = 0
    pq = [(0, start)]
    previous = {node: None for node in graph}

    while pq:
        current_distance, current_node = heapq.heappop(pq)
        if current_distance > distances[current_node]:
            continue
        for neighbor, weight in graph[current_node].items():
            distance = current_distance + weight
            if distance < distances[neighbor]:
                distances[neighbor] = distance
                previous[neighbor] = current_node
                heapq.heappush(pq, (distance, neighbor))
    return distances, previous

def shortest_path(graph, start, end):
    distances, previous = dijkstra(graph, start)
    path = []
    current = end
    while current is not None:
        path.insert(0, current)
        current = previous[current]
    return path, distances[end]

# ---- MAIN PROGRAM ----
graph = build_graph()

# Add two more nodes manually
graph['E'] = {'B': 3, 'D': 2, 'F': 6}
graph['F'] = {'C': 7, 'E': 6}

print("\nGraph built successfully!")
print(graph)

# Test algorithm with different source nodes
while True:
    source = input("\nEnter source node (or 'exit' to quit): ").strip()
    if source.lower() == 'exit':
        break
    destination = input("Enter destination node: ").strip()
    if source not in graph or destination not in graph:
        print("Invalid nodes, try again.")
        continue
    path, distance = shortest_path(graph, source, destination)
    print(f"Shortest path from {source} to {destination}: {' -> '.join(path)} with total distance {distance}")
# Out:
# Enter number of nodes: 4
# Enter node name: a
# Enter node name: b
# Enter node name: c
# Enter node name: d
# Enter number of edges: 4
# Enter start node: a
# Enter end node: c
# Enter weight from a to c: 2
# Enter start node: b
# Enter end node: c
# Enter weight from b to c: 3
# Enter start node: a
# Enter end node: d
# Enter weight from a to d: 4
# Enter start node: c
# Enter end node: d
# Enter weight from c to d: 5
#
# Graph built successfully!
# {'a': {'c': 2, 'd': 4}, 'b': {'c': 3}, 'c': {'a': 2, 'b': 3, 'd': 5}, 'd': {'a': 4, 'c': 5}, 'E': {'B': 3, 'D': 2, 'F': 6}, 'F': {'C': 7, 'E': 6}}
#
# Enter source node (or 'exit' to quit): a
# Enter destination node: d
# Shortest path from a to d: a -> d with total distance 4
#
# Enter source node (or 'exit' to quit): exit
